# %% [markdown]
# # EDA

# %% [markdown]
# - The os module has a perfect method to list files in a directory.
# - Pandas json normalize could work here but is not necessary to convert the JSON data to a dataframe.
# - You may need a nested for-loop to access each sale!
# - We've put a lot of time into creating the structure of this repository, and it's a good example for future projects.  In the file functions_variables.py, there is an example function that you can import and use.  If you have any variables, functions or classes that you want to make, they can be put in the functions_variables.py file and imported into a notebook.  Note that only .py files can be imported into a notebook. If you want to import everything from a .py file, you can use the following:
# ```python
# from functions_variables import *
# ```
# If you just import functions_variables, then each object from the file will need to be prepended with "functions_variables"\
# Using this .py file will keep your notebooks very organized and make it easier to reuse code between notebooks.

# %%
# (this is not an exhaustive list of libraries)
import pandas as pd
import numpy as np
import os
import json
from pprint import pprint
from functions_variables import encode_tags
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Importing

# %%
# load one file first to see what type of data you're dealing with and what attributes it has
json_file = open('../data/AK_Juneau_0.json')
data = json.load(json_file)
df = pd.json_normalize(data['data']['results'])
df.head()
# Out:
#        last_update_date                                               tags  \
# 0  2023-09-19T20:52:50Z  [carport, community_outdoor_space, cul_de_sac,...
# 1                  None                                               None
# 2                  None                                               None
# 3                  None                                               None
# 4                  None                                               None
#
#                                            permalink status  \
# 0       9453-Herbert-Pl_Juneau_AK_99801_M90744-30767   sold
# 1  8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 2      4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 3  17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 4  9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
#
#                      list_date open_houses  \
# 0  2023-06-29T21:16:25.000000Z        None
# 1                         None        None
# 2                         None        None
# 3                         None        None
# 4                         None        None
#
#                                             branding  list_price property_id  \
# 0  [{'name': 'EXP Realty LLC - Southeast Alaska',...    554950.0  9074430767
# 1  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  9424983842
# 2  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  9479068516
# 3  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  9879331943
# 4  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  9521639574
#
#                                               photos  ...  \
# 0  [{'tags': [{'label': 'house_view', 'probabilit...  ...
# 1                                               None  ...
# 2                                               None  ...
# 3                                               None  ...
# 4                                               None  ...
#
#   location.address.state_code              location.address.line  \
# 0                          AK                    9453 Herbert Pl
# 1                          AK           8477 Thunder Mountain Rd
# 2                          AK                   4515 Glacier Hwy
# 3                          AK            17850 Point Stephens Rd
# 4                          AK  9951 Stephen Richards Memorial Dr
#
#                             location.street_view_url  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
# 1  https://maps.googleapis.com/maps/api/streetvie...
# 2  https://maps.googleapis.com/maps/api/streetvie...
# 3  https://maps.googleapis.com/maps/api/streetvie...
# 4  https://maps.googleapis.com/maps/api/streetvie...
#
#    location.county.fips_code  location.county.name primary_photo  source  \
# 0                       None                Juneau           NaN     NaN
# 1                       None                Juneau           NaN     NaN
# 2                       None                Juneau           NaN     NaN
# 3                       None                Juneau           NaN     NaN
# 4                       None                Juneau           NaN     NaN
#
#   products  location.address.coordinate other_listings
# 0      NaN                          NaN            NaN
# 1      NaN                          NaN            NaN
# 2      NaN                          NaN            NaN
# 3      NaN                          NaN            NaN
# 4      NaN                          NaN            NaN
#
# [5 rows x 64 columns]

# %%
df.columns
# Out:
# Index(['last_update_date', 'tags', 'permalink', 'status', 'list_date',
#        'open_houses', 'branding', 'list_price', 'property_id', 'photos',
#        'community', 'virtual_tours', 'listing_id', 'price_reduced_amount',
#        'matterport', 'primary_photo.href', 'source.plan_id', 'source.agents',
#        'source.spec_id', 'source.type', 'description.year_built',
#        'description.baths_3qtr', 'description.sold_date',
#        'description.sold_price', 'description.baths_full', 'description.name',
#        'description.baths_half', 'description.lot_sqft', 'description.sqft',
#        'description.baths', 'description.sub_type', 'description.baths_1qtr',
#        'description.garage', 'description.stories', 'description.beds',
#        'description.type', 'lead_attributes.show_contact_an_agent',
#        'flags.is_new_construction', 'flags.is_for_rent',
#        'flags.is_subdivision', 'flags.is_contingent', 'flags.is_price_reduced',
#        'flags.is_pending', 'flags.is_foreclosure', 'flags.is_plan',
#        'flags.is_coming_soon', 'flags.is_new_listing', 'products.brand_name',
#        'other_listings.rdc', 'location.address.postal_code',
#        'location.address.state', 'location.address.coordinate.lon',
#        'location.address.coordinate.lat', 'location.address.city',
#        'location.address.state_code', 'location.address.line',
#        'location.street_view_url', 'location.county.fips_code',
#        'location.county.name', 'primary_photo', 'source', 'products',
#        'location.address.coordinate', 'other_listings'],
#       dtype='object')

# %%
# loop over all files and put them into a dataframe
# get all the files in the data folder with the .json extension
files = [file for file in os.listdir('../data') if file.endswith('.json')]
print(len(files))

# loop over all files and put them into a dataframe
df_list = []
for file in files:
    json_file = open(f'../data/{file}')
    data = json.load(json_file)
    df = pd.json_normalize(data['data']['results'])
    df_list.append(df)

final_df = pd.concat(df_list, ignore_index=True)
final_df
# Out:
# 250
#           last_update_date                                               tags  \
# 0     2023-09-19T20:52:50Z  [carport, community_outdoor_space, cul_de_sac,...
# 1                     None                                               None
# 2                     None                                               None
# 3                     None                                               None
# 4                     None                                               None
# ...                    ...                                                ...
# 8186                   NaN                                                NaN
# 8187                   NaN                                                NaN
# 8188                   NaN                                                NaN
# 8189                   NaN                                                NaN
# 8190                   NaN                                                NaN
#
#                                               permalink status  \
# 0          9453-Herbert-Pl_Juneau_AK_99801_M90744-30767   sold
# 1     8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 2         4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 3     17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 4     9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
# ...                                                 ...    ...
# 8186                                                NaN    NaN
# 8187                                                NaN    NaN
# 8188                                                NaN    NaN
# 8189                                                NaN    NaN
# 8190                                                NaN    NaN
#
#                         list_date open_houses  \
# 0     2023-06-29T21:16:25.000000Z        None
# 1                            None        None
# 2                            None        None
# 3                            None        None
# 4                            None        None
# ...                           ...         ...
# 8186                          NaN         NaN
# 8187                          NaN         NaN
# 8188                          NaN         NaN
# 8189                          NaN         NaN
# 8190                          NaN         NaN
#
#                                                branding list_price  \
# 0     [{'name': 'EXP Realty LLC - Southeast Alaska',...   554950.0
# 1     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# 2     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# 3     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# 4     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# ...                                                 ...        ...
# 8186                                                NaN        NaN
# 8187                                                NaN        NaN
# 8188                                                NaN        NaN
# 8189                                                NaN        NaN
# 8190                                                NaN        NaN
#
#      property_id                                             photos  ...  \
# 0     9074430767  [{'tags': [{'label': 'house_view', 'probabilit...  ...
# 1     9424983842                                               None  ...
# 2     9479068516                                               None  ...
# 3     9879331943                                               None  ...
# 4     9521639574                                               None  ...
# ...          ...                                                ...  ...
# 8186         NaN                                                NaN  ...
# 8187         NaN                                                NaN  ...
# 8188         NaN                                                NaN  ...
# 8189         NaN                                                NaN  ...
# 8190         NaN                                                NaN  ...
#
#      location.county.fips_code location.county.name primary_photo source  \
# 0                         None               Juneau           NaN    NaN
# 1                         None               Juneau           NaN    NaN
# 2                         None               Juneau           NaN    NaN
# 3                         None               Juneau           NaN    NaN
# 4                         None               Juneau           NaN    NaN
# ...                        ...                  ...           ...    ...
# 8186                       NaN                  NaN           NaN    NaN
# 8187                       NaN                  NaN           NaN    NaN
# 8188                       NaN                  NaN           NaN    NaN
# 8189                       NaN                  NaN           NaN    NaN
# 8190                       NaN                  NaN           NaN    NaN
#
#      products location.address.coordinate other_listings  \
# 0         NaN                         NaN            NaN
# 1         NaN                         NaN            NaN
# 2         NaN                         NaN            NaN
# 3         NaN                         NaN            NaN
# 4         NaN                         NaN            NaN
# ...       ...                         ...            ...
# 8186      NaN                         NaN            NaN
# 8187      NaN                         NaN            NaN
# 8188      NaN                         NaN            NaN
# 8189      NaN                         NaN            NaN
# 8190      NaN                         NaN            NaN
#
#      community.advertisers community.description.name location.county
# 0                      NaN                        NaN             NaN
# 1                      NaN                        NaN             NaN
# 2                      NaN                        NaN             NaN
# 3                      NaN                        NaN             NaN
# 4                      NaN                        NaN             NaN
# ...                    ...                        ...             ...
# 8186                   NaN                        NaN             NaN
# 8187                   NaN                        NaN             NaN
# 8188                   NaN                        NaN             NaN
# 8189                   NaN                        NaN             NaN
# 8190                   NaN                        NaN             NaN
#
# [8191 rows x 67 columns]

# %% [markdown]
# ## Data Cleaning and Wrangling

# %% [markdown]
# At this point, ensure that you have all sales in a dataframe.
# - Take a quick look at your data (i.e. `.info()`, `.describe()`) - what do you see?
# - Is each cell one value, or do some cells have lists?
# - What are the data types of each column?
# - Some sales may not actually include the sale price (target).  These rows should be dropped.
# - There are a lot of NA/None values.  Should these be dropped or replaced with something?
#     - You can drop rows or use various methods to fills NA's - use your best judgement for each column
#     - i.e. for some columns (like Garage), NA probably just means no Garage, so 0
# - Drop columns that aren't needed
#     - Don't keep the list price because it will be too close to the sale price. Assume we want to predict the price of houses not yet listed

# %%
# load and concatenate data here
# drop or replace values as necessary
print(final_df.info())
print(final_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8191 entries, 0 to 8190
# Data columns (total 67 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   last_update_date                       8125 non-null   object
#  1   tags                                   7638 non-null   object
#  2   permalink                              8159 non-null   object
#  3   status                                 8159 non-null   object
#  4   list_date                              7752 non-null   object
#  5   open_houses                            0 non-null      object
#  6   branding                               8159 non-null   object
#  7   list_price                             7721 non-null   object
#  8   property_id                            8159 non-null   object
#  9   photos                                 7403 non-null   object
#  10  community                              0 non-null      object
#  11  virtual_tours                          1351 non-null   object
#  12  listing_id                             7752 non-null   object
#  13  price_reduced_amount                   2484 non-null   object
#  14  matterport                             8159 non-null   object
#  15  primary_photo.href                     7403 non-null   object
#  16  source.plan_id                         5 non-null      object
#  17  source.agents                          7752 non-null   object
#  18  source.spec_id                         5 non-null      object
#  19  source.type                            7752 non-null   object
#  20  description.year_built                 7316 non-null   object
#  21  description.baths_3qtr                 566 non-null    object
#  22  description.sold_date                  8159 non-null   object
#  23  description.sold_price                 6716 non-null   object
#  24  description.baths_full                 7311 non-null   object
#  25  description.name                       0 non-null      object
#  26  description.baths_half                 2281 non-null   object
#  27  description.lot_sqft                   6991 non-null   object
#  28  description.sqft                       7323 non-null   object
#  29  description.baths                      7980 non-null   float64
#  30  description.sub_type                   1427 non-null   object
#  31  description.baths_1qtr                 0 non-null      object
#  32  description.garage                     4448 non-null   object
#  33  description.stories                    6260 non-null   object
#  34  description.beds                       7504 non-null   object
#  35  description.type                       8125 non-null   object
#  36  lead_attributes.show_contact_an_agent  8159 non-null   object
#  37  flags.is_new_construction              0 non-null      object
#  38  flags.is_for_rent                      0 non-null      object
#  39  flags.is_subdivision                   0 non-null      object
#  40  flags.is_contingent                    0 non-null      object
#  41  flags.is_price_reduced                 2484 non-null   object
#  42  flags.is_pending                       0 non-null      object
#  43  flags.is_foreclosure                   42 non-null     object
#  44  flags.is_plan                          0 non-null      object
#  45  flags.is_coming_soon                   0 non-null      object
#  46  flags.is_new_listing                   7752 non-null   object
#  47  products.brand_name                    7673 non-null   object
#  48  other_listings.rdc                     7856 non-null   object
#  49  location.address.postal_code           8159 non-null   object
#  50  location.address.state                 8159 non-null   object
#  51  location.address.coordinate.lon        7909 non-null   float64
#  52  location.address.coordinate.lat        7909 non-null   float64
#  53  location.address.city                  8154 non-null   object
#  54  location.address.state_code            8159 non-null   object
#  55  location.address.line                  8144 non-null   object
#  56  location.street_view_url               8159 non-null   object
#  57  location.county.fips_code              7588 non-null   object
#  58  location.county.name                   8149 non-null   object
#  59  primary_photo                          0 non-null      object
#  60  source                                 0 non-null      object
#  61  products                               0 non-null      object
#  62  location.address.coordinate            0 non-null      object
#  63  other_listings                         0 non-null      object
#  64  community.advertisers                  5 non-null      object
#  65  community.description.name             5 non-null      object
#  66  location.county                        0 non-null      float64
# dtypes: float64(4), object(63)
# memory usage: 4.2+ MB
# None
#        description.baths  location.address.coordinate.lon  \
# count        7980.000000                      7909.000000
# mean            2.131203                       -92.206522
# std             1.175940                        15.888886
# min             0.000000                      -157.810583
# 25%             1.000000                      -104.971611
# 50%             2.000000                       -89.333131
# 75%             3.000000                       -78.617690
# max             9.000000                       -71.006343
#
#        location.address.coordinate.lat  location.county
# count                      7909.000000              0.0
# mean                         39.009689              NaN
# std                           4.374553              NaN
# min                          21.277707              NaN
# 25%                          35.688084              NaN
# 50%                          39.698210              NaN
# 75%                          41.832266              NaN
# max                          58.396178              NaN

# %%
# drop open house,property_id,photos column
final_df = final_df.drop(columns=['open_houses', 'property_id', 'photos','community','virtual_tours','listing_id','primary_photo.href','source.plan_id','source.agents','source.spec_id','source.type',
                                  'description.name','description.baths_1qtr','flags.is_new_construction','flags.is_for_rent','flags.is_subdivision','flags.is_contingent','flags.is_pending','flags.is_price_reduced',
                                  'flags.is_foreclosure','flags.is_plan','flags.is_coming_soon','other_listings.rdc','location.address.coordinate.lon','location.address.coordinate.lat','location.address.line',
                                  'location.street_view_url','location.county.fips_code','location.county.name','primary_photo','source','other_listings','location.address.coordinate','community.advertisers',
                                  'community.description.name','location.county','products','last_update_date','list_date','description.sold_date','status','permalink','products.brand_name','flags.is_new_listing','matterport'], axis=1)
final_df
# Out:
#                                                    tags  \
# 0     [carport, community_outdoor_space, cul_de_sac,...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 8186                                                NaN
# 8187                                                NaN
# 8188                                                NaN
# 8189                                                NaN
# 8190                                                NaN
#
#                                                branding list_price  \
# 0     [{'name': 'EXP Realty LLC - Southeast Alaska',...   554950.0
# 1     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# 2     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# 3     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# 4     [{'name': None, 'photo': None, 'type': 'Office'}]        NaN
# ...                                                 ...        ...
# 8186                                                NaN        NaN
# 8187                                                NaN        NaN
# 8188                                                NaN        NaN
# 8189                                                NaN        NaN
# 8190                                                NaN        NaN
#
#      price_reduced_amount description.year_built description.baths_3qtr  \
# 0                 45000.0                 1963.0                   None
# 1                     NaN                    NaN                   None
# 2                     NaN                    NaN                   None
# 3                     NaN                    NaN                   None
# 4                     NaN                    NaN                   None
# ...                   ...                    ...                    ...
# 8186                  NaN                    NaN                    NaN
# 8187                  NaN                    NaN                    NaN
# 8188                  NaN                    NaN                    NaN
# 8189                  NaN                    NaN                    NaN
# 8190                  NaN                    NaN                    NaN
#
#      description.sold_price description.baths_full description.baths_half  \
# 0                      None                    2.0                   None
# 1                      None                    NaN                   None
# 2                      None                    NaN                   None
# 3                      None                    NaN                   None
# 4                      None                    NaN                   None
# ...                     ...                    ...                    ...
# 8186                    NaN                    NaN                    NaN
# 8187                    NaN                    NaN                    NaN
# 8188                    NaN                    NaN                    NaN
# 8189                    NaN                    NaN                    NaN
# 8190                    NaN                    NaN                    NaN
#
#      description.lot_sqft  ... description.sub_type  description.garage  \
# 0                 10454.0  ...                 None                 1.0
# 1                     NaN  ...                 None                 NaN
# 2                     NaN  ...                 None                 NaN
# 3                     NaN  ...                 None                 NaN
# 4                     NaN  ...                 None                 NaN
# ...                   ...  ...                  ...                 ...
# 8186                  NaN  ...                  NaN                 NaN
# 8187                  NaN  ...                  NaN                 NaN
# 8188                  NaN  ...                  NaN                 NaN
# 8189                  NaN  ...                  NaN                 NaN
# 8190                  NaN  ...                  NaN                 NaN
#
#      description.stories description.beds description.type  \
# 0                    NaN              3.0    single_family
# 1                    NaN              NaN             None
# 2                    NaN              NaN             None
# 3                    NaN              NaN             None
# 4                    NaN              NaN             None
# ...                  ...              ...              ...
# 8186                 NaN              NaN              NaN
# 8187                 NaN              NaN              NaN
# 8188                 NaN              NaN              NaN
# 8189                 NaN              NaN              NaN
# 8190                 NaN              NaN              NaN
#
#      lead_attributes.show_contact_an_agent location.address.postal_code  \
# 0                                     True                        99801
# 1                                     True                        99801
# 2                                     True                        99801
# 3                                     True                        99801
# 4                                     True                        99801
# ...                                    ...                          ...
# 8186                                   NaN                          NaN
# 8187                                   NaN                          NaN
# 8188                                   NaN                          NaN
# 8189                                   NaN                          NaN
# 8190                                   NaN                          NaN
#
#      location.address.state location.address.city location.address.state_code
# 0                    Alaska                Juneau                          AK
# 1                    Alaska                Juneau                          AK
# 2                    Alaska                Juneau                          AK
# 3                    Alaska                Juneau                          AK
# 4                    Alaska                Juneau                          AK
# ...                     ...                   ...                         ...
# 8186                    NaN                   NaN                         NaN
# 8187                    NaN                   NaN                         NaN
# 8188                    NaN                   NaN                         NaN
# 8189                    NaN                   NaN                         NaN
# 8190                    NaN                   NaN                         NaN
#
# [8191 rows x 22 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8191 entries, 0 to 8190
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tags                                   7638 non-null   object
#  1   branding                               8159 non-null   object
#  2   list_price                             7721 non-null   object
#  3   price_reduced_amount                   2484 non-null   object
#  4   description.year_built                 7316 non-null   object
#  5   description.baths_3qtr                 566 non-null    object
#  6   description.sold_price                 6716 non-null   object
#  7   description.baths_full                 7311 non-null   object
#  8   description.baths_half                 2281 non-null   object
#  9   description.lot_sqft                   6991 non-null   object
#  10  description.sqft                       7323 non-null   object
#  11  description.baths                      7980 non-null   float64
#  12  description.sub_type                   1427 non-null   object
#  13  description.garage                     4448 non-null   object
#  14  description.stories                    6260 non-null   object
#  15  description.beds                       7504 non-null   object
#  16  description.type                       8125 non-null   object
#  17  lead_attributes.show_contact_an_agent  8159 non-null   object
#  18  location.address.postal_code           8159 non-null   object
#  19  location.address.state                 8159 non-null   object
#  20  location.address.city                  8154 non-null   object
#  21  location.address.state_code            8159 non-null   object
# dtypes: float64(1), object(21)
# memory usage: 1.4+ MB

# %%
final_df['lead_attributes.show_contact_an_agent'].value_counts()
# Out:
# True     8066
# False      93
# Name: lead_attributes.show_contact_an_agent, dtype: int64

# %%
# fill null values
# price_reduced_amount
final_df['price_reduced_amount'] = final_df['price_reduced_amount'].fillna(0)
# description.baths_3qtr
final_df['description.baths_3qtr'] = final_df['description.baths_3qtr'].fillna(0)
# description.baths_full
mean_baths_full = final_df['description.baths_full'].mean()
final_df['description.baths_full'] = final_df['description.baths_full'].fillna(mean_baths_full)
# description.baths_half
final_df['description.baths_half'] = final_df['description.baths_half'].fillna(0)
# description.beds
final_df['description.beds'] = final_df['description.beds'].fillna(0)
# description.lot_sqft mean
mean_lot_sqft = final_df['description.lot_sqft'].mean()
final_df['description.lot_sqft'] = final_df['description.lot_sqft'].fillna(mean_lot_sqft)
# description.sqft mean
mean_sqft = final_df['description.sqft'].mean()
final_df['description.sqft'] = final_df['description.sqft'].fillna(mean_sqft)
# description.sub_type
final_df['description.sub_type'] = final_df['description.sub_type'].fillna('Unknown')
# description.garage
final_df['description.garage'] = final_df['description.garage'].fillna(0)
# description.stories 
median_stories = final_df['description.stories'].median()
final_df['description.stories'] = final_df['description.stories'].fillna(median_stories)
# description.beds
median_beds = final_df['description.beds'].median()
final_df['description.beds'] = final_df['description.beds'].fillna(median_beds)
# description.type
final_df['description.type'] = final_df['description.type'].fillna('Unknown')
# flags.is_new_listing
# final_df['flags.is_new_listing'] = final_df['flags.is_new_listing'].fillna(True)
# # products.brand_name
# final_df['products.brand_name'] = final_df['products.brand_name'].fillna('Unknown')
# description.year_built
median_year_built = final_df['description.year_built'].median()
final_df['description.year_built'] = final_df['description.year_built'].fillna(median_year_built)
final_df['description.year_built'] = final_df['description.year_built'].astype(int)
# description.baths
mean_baths = final_df['description.baths'].mean()
final_df['description.baths'] = final_df['description.baths'].fillna(mean_baths)
# list_price
final_df['list_price'] = final_df['list_price'].fillna(0)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8191 entries, 0 to 8190
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tags                                   7638 non-null   object
#  1   branding                               8159 non-null   object
#  2   list_price                             8191 non-null   float64
#  3   price_reduced_amount                   8191 non-null   float64
#  4   description.year_built                 8191 non-null   int32
#  5   description.baths_3qtr                 8191 non-null   float64
#  6   description.sold_price                 6716 non-null   object
#  7   description.baths_full                 8191 non-null   float64
#  8   description.baths_half                 8191 non-null   float64
#  9   description.lot_sqft                   8191 non-null   float64
#  10  description.sqft                       8191 non-null   float64
#  11  description.baths                      8191 non-null   float64
#  12  description.sub_type                   8191 non-null   object
#  13  description.garage                     8191 non-null   float64
#  14  description.stories                    8191 non-null   float64
#  15  description.beds                       8191 non-null   float64
#  16  description.type                       8191 non-null   object
#  17  lead_attributes.show_contact_an_agent  8159 non-null   object
#  18  location.address.postal_code           8159 non-null   object
#  19  location.address.state                 8159 non-null   object
#  20  location.address.city                  8154 non-null   object
#  21  location.address.state_code            8159 non-null   object
# dtypes: float64(11), int32(1), object(10)
# memory usage: 1.3+ MB

# %%
# drop description.sold_price is null
final_df = final_df[final_df['description.sold_price'].notna()]
final_df = final_df[final_df['description.sold_price'] != 0]
final_df = final_df[final_df['location.address.city'].notna()]
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6711 entries, 30 to 8185
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tags                                   6325 non-null   object
#  1   branding                               6711 non-null   object
#  2   list_price                             6711 non-null   float64
#  3   price_reduced_amount                   6711 non-null   float64
#  4   description.year_built                 6711 non-null   int32
#  5   description.baths_3qtr                 6711 non-null   float64
#  6   description.sold_price                 6711 non-null   object
#  7   description.baths_full                 6711 non-null   float64
#  8   description.baths_half                 6711 non-null   float64
#  9   description.lot_sqft                   6711 non-null   float64
#  10  description.sqft                       6711 non-null   float64
#  11  description.baths                      6711 non-null   float64
#  12  description.sub_type                   6711 non-null   object
#  13  description.garage                     6711 non-null   float64
#  14  description.stories                    6711 non-null   float64
#  15  description.beds                       6711 non-null   float64
#  16  description.type                       6711 non-null   object
#  17  lead_attributes.show_contact_an_agent  6711 non-null   object
#  18  location.address.postal_code           6711 non-null   object
#  19  location.address.state                 6711 non-null   object
#  20  location.address.city                  6711 non-null   object
#  21  location.address.state_code            6711 non-null   object
# dtypes: float64(11), int32(1), object(10)
# memory usage: 1.2+ MB

# %%
# def extract_name(branding):
#     if isinstance(branding, list) and len(branding) > 0:
#         return branding[0].get('name', '')
#     return ''

# def extract_type(branding):
#     if isinstance(branding, list) and len(branding) > 0:
#         return branding[0].get('type', '')
#     return ''

# final_df['branding_name'] = final_df['branding'].apply(extract_name)
# final_df['branding_type'] = final_df['branding'].apply(extract_type)
final_df = final_df.drop(columns=['branding'])
# final_df.head(15)

# %% [markdown]
# ### Dealing with Tags

# %% [markdown]
# Consider the fact that with tags, there are a lot of categorical variables.
# - How many columns would we have if we OHE tags, city and state?
# - Perhaps we can get rid of tags that have a low frequency.

# %%
# OHE categorical variables/ tags here
# tags will have to be done manually
final_df['tags'].value_counts()
# Out:
# [big_lot]                                                                                                                                                                                                                                           62
# [rental_property]                                                                                                                                                                                                                                   54
# [basement, big_lot]                                                                                                                                                                                                                                 15
# [basement, rental_property]                                                                                                                                                                                                                         15
# [basement]                                                                                                                                                                                                                                          15
#                                                                                                                                                                                                                                                     ..
# [central_air, central_heat, single_story, garage_1_or_more, garage_2_or_more, fenced_yard, no_hoa, farm, ranch, shopping]                                                                                                                            1
# [central_air, city_view, fireplace, forced_air, hardwood_floors, view, single_story, garage_1_or_more, garage_2_or_more]                                                                                                                             1
# [central_air, city_view, community_outdoor_space, forced_air, hardwood_floors, laundry_room, view, single_story, farm, ranch, maintenance]                                                                                                           1
# [central_air, community_outdoor_space, corner_lot, dishwasher, fireplace, forced_air, hardwood_floors, washer_dryer, basement, two_or_more_stories, garage_1_or_more, garage_2_or_more, high_ceiling, front_porch, ensuite]                          1
# [central_air, central_heat, community_outdoor_space, community_security_features, corner_lot, cul_de_sac, dishwasher, energy_efficient, fireplace, hardwood_floors, laundry_room, single_story, garage_1_or_more, garage_2_or_more, fenced_yard]     1
# Name: tags, Length: 1345, dtype: int64

# %%
## Create two empty lists to store tags and other data separately
tags_list = []
other_data = []

## Iterate over the tags column
for sublist in final_df['tags']:
    if isinstance(sublist, list):
        tags_list.extend(sublist)
    else:
        other_data.append(sublist)
        
## Convert the tags list to a Series and calculate the frequency        
tags_series = pd.Series(tags_list)
tags_freq = tags_series.value_counts()

## Convert the other data to a Series
other_series = pd.Series(other_data)

print("Tags Frequency:")
print(tags_freq)
type(tags_freq)

# print("\nOther Data:")
# print(other_series)
# Out:
# Tags Frequency:
# garage_1_or_more           3773
# central_air                3410
# community_outdoor_space    3117
# dishwasher                 2970
# basement                   2931
#                            ...
# courtyard_entry               5
# greenhouse                    5
# two_kitchen                   5
# boat_dock                     5
# dual_master_bedroom           5
# Length: 152, dtype: int64
# pandas.core.series.Series

# %%
# looking for tags with frequency less than 10
tags_freq[tags_freq > 1000]
len(tags_freq[tags_freq > 1000])
# Out:
# 21

# %%
final_df_copy = final_df.copy()
final_df_copy = encode_tags(final_df_copy)
final_df_copy
# Out:
#                                                    tags  list_price  \
# 30    [central_air, central_heat, community_outdoor_...    129900.0
# 31    [city_view, hardwood_floors, two_or_more_stori...     88000.0
# 32    [carport, central_air, central_heat, dishwashe...    149000.0
# 33    [carport, central_air, city_view, community_ou...     68000.0
# 34    [city_view, single_story, big_yard, fenced_yar...    169999.0
# ...                                                 ...         ...
# 8181  [central_air, forced_air, basement, two_or_mor...     98000.0
# 8182                                [basement, big_lot]     49999.0
# 8183                                [basement, big_lot]    133000.0
# 8184                                  [rental_property]     75000.0
# 8185  [central_air, garage_1_or_more, basement, sing...    112600.0
#
#       price_reduced_amount  description.year_built  description.baths_3qtr  \
# 30                     0.0                    1998                     0.0
# 31                  3000.0                    1945                     0.0
# 32                     0.0                    1969                     0.0
# 33                  9000.0                    1955                     0.0
# 34                  5000.0                    1984                     0.0
# ...                    ...                     ...                     ...
# 8181                   0.0                    1910                     0.0
# 8182                   0.0                    1975                     0.0
# 8183                   0.0                    1975                     0.0
# 8184                   0.0                    1975                     0.0
# 8185                   0.0                    1950                     0.0
#
#      description.sold_price  description.baths_full  description.baths_half  \
# 30                   129900                 2.00000                     0.0
# 31                    88500                 2.00000                     0.0
# 32                   145000                 2.00000                     0.0
# 33                    65000                 2.00000                     0.0
# 34                   169000                 2.00000                     0.0
# ...                     ...                     ...                     ...
# 8181                  99000                 1.00000                     0.0
# 8182                  29700                 1.00000                     0.0
# 8183                 162250                 1.00000                     0.0
# 8184                  63800                 1.88743                     0.0
# 8185                 115500                 2.00000                     0.0
#
#       description.lot_sqft  description.sqft  ...  city_view  \
# 30            11761.000000       1478.000000  ...          0
# 31             6534.000000       1389.000000  ...          1
# 32            17424.000000       2058.000000  ...          0
# 33             9712.000000       1432.000000  ...          1
# 34            10890.000000       1804.000000  ...          1
# ...                    ...               ...  ...        ...
# 8181           4792.000000       1214.000000  ...          0
# 8182           7841.000000        988.000000  ...          0
# 8183          65340.000000       1470.000000  ...          0
# 8184         251094.946789       1933.848559  ...          0
# 8185          52272.000000       3858.000000  ...          0
#
#      two_or_more_stories  recreation_facilities  shopping  washer_dryer  \
# 30                     0                      0         0             0
# 31                     1                      0         0             0
# 32                     0                      0         0             0
# 33                     0                      1         0             0
# 34                     0                      0         0             0
# ...                  ...                    ...       ...           ...
# 8181                   1                      0         0             0
# 8182                   0                      0         0             0
# 8183                   0                      0         0             0
# 8184                   0                      0         0             0
# 8185                   0                      0         0             0
#
#      basement view forced_air family_room dining_room
# 30          0    0          0           0           0
# 31          0    0          0           0           0
# 32          0    0          0           0           0
# 33          0    0          0           0           0
# 34          0    0          0           0           0
# ...       ...  ...        ...         ...         ...
# 8181        1    0          1           0           0
# 8182        1    0          0           0           0
# 8183        1    0          0           0           0
# 8184        0    0          0           0           0
# 8185        1    0          0           0           0
#
# [6711 rows x 42 columns]

# %%
# drop the tags column
final_df_copy = final_df_copy.drop(columns=['tags'], axis=1)
final_df_copy
# Out:
#       list_price  price_reduced_amount  description.year_built  \
# 30      129900.0                   0.0                    1998
# 31       88000.0                3000.0                    1945
# 32      149000.0                   0.0                    1969
# 33       68000.0                9000.0                    1955
# 34      169999.0                5000.0                    1984
# ...          ...                   ...                     ...
# 8181     98000.0                   0.0                    1910
# 8182     49999.0                   0.0                    1975
# 8183    133000.0                   0.0                    1975
# 8184     75000.0                   0.0                    1975
# 8185    112600.0                   0.0                    1950
#
#       description.baths_3qtr description.sold_price  description.baths_full  \
# 30                       0.0                 129900                 2.00000
# 31                       0.0                  88500                 2.00000
# 32                       0.0                 145000                 2.00000
# 33                       0.0                  65000                 2.00000
# 34                       0.0                 169000                 2.00000
# ...                      ...                    ...                     ...
# 8181                     0.0                  99000                 1.00000
# 8182                     0.0                  29700                 1.00000
# 8183                     0.0                 162250                 1.00000
# 8184                     0.0                  63800                 1.88743
# 8185                     0.0                 115500                 2.00000
#
#       description.baths_half  description.lot_sqft  description.sqft  \
# 30                       0.0          11761.000000       1478.000000
# 31                       0.0           6534.000000       1389.000000
# 32                       0.0          17424.000000       2058.000000
# 33                       0.0           9712.000000       1432.000000
# 34                       0.0          10890.000000       1804.000000
# ...                      ...                   ...               ...
# 8181                     0.0           4792.000000       1214.000000
# 8182                     0.0           7841.000000        988.000000
# 8183                     0.0          65340.000000       1470.000000
# 8184                     0.0         251094.946789       1933.848559
# 8185                     0.0          52272.000000       3858.000000
#
#       description.baths  ... city_view  two_or_more_stories  \
# 30                  2.0  ...         0                    0
# 31                  2.0  ...         1                    1
# 32                  2.0  ...         0                    0
# 33                  2.0  ...         1                    0
# 34                  2.0  ...         1                    0
# ...                 ...  ...       ...                  ...
# 8181                1.0  ...         0                    1
# 8182                1.0  ...         0                    0
# 8183                1.0  ...         0                    0
# 8184                0.0  ...         0                    0
# 8185                2.0  ...         0                    0
#
#       recreation_facilities  shopping washer_dryer basement view forced_air  \
# 30                        0         0            0        0    0          0
# 31                        0         0            0        0    0          0
# 32                        0         0            0        0    0          0
# 33                        1         0            0        0    0          0
# 34                        0         0            0        0    0          0
# ...                     ...       ...          ...      ...  ...        ...
# 8181                      0         0            0        1    0          1
# 8182                      0         0            0        1    0          0
# 8183                      0         0            0        1    0          0
# 8184                      0         0            0        0    0          0
# 8185                      0         0            0        1    0          0
#
#      family_room dining_room
# 30             0           0
# 31             0           0
# 32             0           0
# 33             0           0
# 34             0           0
# ...          ...         ...
# 8181           0           0
# 8182           0           0
# 8183           0           0
# 8184           0           0
# 8185           0           0
#
# [6711 rows x 41 columns]

# %% [markdown]
# ### Dealing with Cities

# %% [markdown]
# - Sales will vary drastically between cities and states.  Is there a way to keep information about which city it is without OHE?
# - Could we label encode or ordinal encode?  Yes, but this may have undesirable effects, giving nominal data ordinal values.
# - What we can do is use our training data to encode the mean sale price by city as a feature (a.k.a. Target Encoding)
#     - We can do this as long as we ONLY use the training data - we're using the available data to give us a 'starting guess' of the price for each city, without needing to encode city explicitly
# - If you replace cities or states with numerical values (like the mean price), make sure that the data is split so that we don't leak data into the training selection. This is a great time to train test split. Compute on the training data, and join these values to the test data
# - Note that you *may* have cities in the test set that are not in the training set. You don't want these to be NA, so maybe you can fill them with the overall mean

# %%
# perform train test split here
# do something with state and city
print(final_df_copy['location.address.city'].value_counts())
print(final_df_copy['location.address.state'].value_counts())
# Out:
# Montgomery     210
# Raleigh        210
# Frankfort      210
# Harrisburg     210
# Lansing        210
#               ...
# Alexander        2
# Old Hickory      2
# Tolleson         1
# Hermitage        1
# Galloway         1
# Name: location.address.city, Length: 84, dtype: int64
# Alabama           210
# Michigan          210
# Wisconsin         210
# Washington        210
# Virginia          210
# Rhode Island      210
# Pennsylvania      210
# Oregon            210
# Oklahoma          210
# New York          210
# Nevada            210
# New Jersey        210
# Nebraska          210
# North Carolina    210
# Arkansas          210
# Minnesota         210
# Maryland          210
# Massachusetts     210
# Arizona           210
# California        210
# Colorado          210
# Connecticut       210
# Delaware          210
# Florida           210
# Georgia           210
# Iowa              210
# Indiana           210
# Kentucky          210
# Ohio              205
# West Virginia     204
# Illinois          170
# South Carolina    160
# Tennessee          80
# Hawaii              6
# New Hampshire       6
# Name: location.address.state, dtype: int64

# %%
# train test split
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(final_df_copy, test_size=0.2, random_state=42)

train_df
# Out:
#       list_price  price_reduced_amount  description.year_built  \
# 5285    415000.0               10000.0                    2020
# 7802    320000.0                   0.0                    1978
# 1837    300000.0                   0.0                    1983
# 4929     80000.0                   0.0                    1836
# 3432    589999.0                9901.0                    2013
# ...          ...                   ...                     ...
# 4600    269000.0                   0.0                    1976
# 6236    329000.0               21000.0                    1948
# 6271     25000.0                   0.0                    1975
# 6435     25000.0                   0.0                    1975
# 890     539900.0               19100.0                    1951
#
#       description.baths_3qtr description.sold_price  description.baths_full  \
# 5285                     0.0                 415000                 2.00000
# 7802                     0.0                 320000                 1.00000
# 1837                     0.0                 287000                 1.00000
# 4929                     0.0                 100000                 1.00000
# 3432                     0.0                 580000                 3.00000
# ...                      ...                    ...                     ...
# 4600                     2.0                 269000                 1.00000
# 6236                     0.0                 330000                 1.00000
# 6271                     0.0                  28000                 1.88743
# 6435                     0.0                  28000                 1.88743
# 890                      1.0                 525000                 1.00000
#
#       description.baths_half  description.lot_sqft  description.sqft  \
# 5285                     1.0                1307.0       1518.000000
# 7802                     1.0                3920.0       1431.000000
# 1837                     0.0                1133.0       1111.000000
# 4929                     0.0                1019.0       1240.000000
# 3432                     1.0                2312.0       2980.000000
# ...                      ...                   ...               ...
# 4600                     0.0                5227.0       1796.000000
# 6236                     0.0                2614.0       1792.000000
# 6271                     0.0               15682.0       1933.848559
# 6435                     0.0               15682.0       1933.848559
# 890                      0.0                7890.0       1351.000000
#
#       description.baths  ... city_view  two_or_more_stories  \
# 5285                3.0  ...         0                    1
# 7802                2.0  ...         0                    0
# 1837                1.0  ...         0                    0
# 4929                1.0  ...         0                    1
# 3432                4.0  ...         0                    1
# ...                 ...  ...       ...                  ...
# 4600                3.0  ...         0                    1
# 6236                1.0  ...         0                    0
# 6271                0.0  ...         0                    0
# 6435                0.0  ...         0                    0
# 890                 2.0  ...         1                    0
#
#       recreation_facilities  shopping washer_dryer basement view forced_air  \
# 5285                      1         0            0        0    1          1
# 7802                      0         0            1        1    0          1
# 1837                      1         1            0        0    0          0
# 4929                      0         0            0        1    0          1
# 3432                      0         0            1        1    0          0
# ...                     ...       ...          ...      ...  ...        ...
# 4600                      0         1            0        1    0          1
# 6236                      0         0            0        1    0          0
# 6271                      0         0            0        0    0          0
# 6435                      0         0            0        0    0          0
# 890                       0         0            0        0    1          1
#
#      family_room dining_room
# 5285           0           0
# 7802           0           0
# 1837           1           0
# 4929           0           0
# 3432           1           0
# ...          ...         ...
# 4600           1           0
# 6236           0           0
# 6271           0           0
# 6435           0           0
# 890            1           1
#
# [5368 rows x 41 columns]

# %%
city_mean_prices = train_df.groupby('location.address.city')['description.sold_price'].mean()
global_mean_price = train_df['description.sold_price'].mean()
train_df['city_mean_price'] = train_df['location.address.city'].map(city_mean_prices)
test_df['city_mean_price'] = test_df['location.address.city'].map(city_mean_prices).fillna(global_mean_price)
train_df = train_df.drop('location.address.city', axis=1)
test_df = test_df.drop('location.address.city', axis=1)

# %%
state_mean_prices = train_df.groupby('location.address.state')['description.sold_price'].mean()
train_df['state_mean_price'] = train_df['location.address.state'].map(state_mean_prices)
global_mean_price = train_df['description.sold_price'].mean()
test_df['state_mean_price'] = test_df['location.address.state'].map(state_mean_prices).fillna(global_mean_price)
train_df = train_df.drop('location.address.state', axis=1)
test_df = test_df.drop('location.address.state', axis=1)

# %%
train_df
# Out:
#       list_price  price_reduced_amount  description.year_built  \
# 5285    415000.0               10000.0                    2020
# 7802    320000.0                   0.0                    1978
# 1837    300000.0                   0.0                    1983
# 4929     80000.0                   0.0                    1836
# 3432    589999.0                9901.0                    2013
# ...          ...                   ...                     ...
# 4600    269000.0                   0.0                    1976
# 6236    329000.0               21000.0                    1948
# 6271     25000.0                   0.0                    1975
# 6435     25000.0                   0.0                    1975
# 890     539900.0               19100.0                    1951
#
#       description.baths_3qtr description.sold_price  description.baths_full  \
# 5285                     0.0                 415000                 2.00000
# 7802                     0.0                 320000                 1.00000
# 1837                     0.0                 287000                 1.00000
# 4929                     0.0                 100000                 1.00000
# 3432                     0.0                 580000                 3.00000
# ...                      ...                    ...                     ...
# 4600                     2.0                 269000                 1.00000
# 6236                     0.0                 330000                 1.00000
# 6271                     0.0                  28000                 1.88743
# 6435                     0.0                  28000                 1.88743
# 890                      1.0                 525000                 1.00000
#
#       description.baths_half  description.lot_sqft  description.sqft  \
# 5285                     1.0                1307.0       1518.000000
# 7802                     1.0                3920.0       1431.000000
# 1837                     0.0                1133.0       1111.000000
# 4929                     0.0                1019.0       1240.000000
# 3432                     1.0                2312.0       2980.000000
# ...                      ...                   ...               ...
# 4600                     0.0                5227.0       1796.000000
# 6236                     0.0                2614.0       1792.000000
# 6271                     0.0               15682.0       1933.848559
# 6435                     0.0               15682.0       1933.848559
# 890                      0.0                7890.0       1351.000000
#
#       description.baths  ... recreation_facilities  shopping  washer_dryer  \
# 5285                3.0  ...                     1         0             0
# 7802                2.0  ...                     0         0             1
# 1837                1.0  ...                     1         1             0
# 4929                1.0  ...                     0         0             0
# 3432                4.0  ...                     0         0             1
# ...                 ...  ...                   ...       ...           ...
# 4600                3.0  ...                     0         1             0
# 6236                1.0  ...                     0         0             0
# 6271                0.0  ...                     0         0             0
# 6435                0.0  ...                     0         0             0
# 890                 2.0  ...                     0         0             0
#
#       basement view forced_air family_room dining_room  city_mean_price  \
# 5285         0    1          1           0           0    522403.574850
# 7802         1    0          1           0           0    428299.358974
# 1837         0    0          0           1           0    695772.727273
# 4929         1    0          1           0           0    204580.645161
# 3432         1    0          0           1           0    740137.076023
# ...        ...  ...        ...         ...         ...              ...
# 4600         1    0          1           1           0    320872.590361
# 6236         1    0          0           0           0    443936.964286
# 6271         0    0          0           0           0    237009.970238
# 6435         0    0          0           0           0    237009.970238
# 890          0    1          1           1           1    616262.445714
#
#       state_mean_price
# 5285     522403.574850
# 7802     429089.714286
# 1837     538346.764706
# 4929     260858.895706
# 3432     740137.076023
# ...                ...
# 4600     320872.590361
# 6236     443936.964286
# 6271     237009.970238
# 6435     237009.970238
# 890      616262.445714
#
# [5368 rows x 41 columns]

# %%
test_df
# Out:
#       list_price  price_reduced_amount  description.year_built  \
# 6040    273900.0               16000.0                    2016
# 277      79900.0                   0.0                    1964
# 5291     75000.0                   0.0                    1975
# 4366    529900.0               10000.0                    1981
# 6427    499000.0               26000.0                    1996
# ...          ...                   ...                     ...
# 7724    209500.0               15000.0                    1979
# 1580    114900.0                   0.0                    2019
# 132     169900.0                   0.0                    1975
# 2585    434500.0                5000.0                    1993
# 6782      5000.0                   0.0                    1975
#
#       description.baths_3qtr description.sold_price  description.baths_full  \
# 6040                     0.0                 267500                 2.00000
# 277                      0.0                  75000                 1.00000
# 5291                     0.0                  50000                 1.88743
# 4366                     0.0                 500000                 2.00000
# 6427                     0.0                 475000                 2.00000
# ...                      ...                    ...                     ...
# 7724                     1.0                 209500                 1.00000
# 1580                     0.0                 112000                 2.00000
# 132                      0.0                 172500                 2.00000
# 2585                     0.0                 421000                 3.00000
# 6782                     0.0                  54167                 1.88743
#
#       description.baths_half  description.lot_sqft  description.sqft  \
# 6040                     0.0           6094.000000       1729.000000
# 277                      1.0           6534.000000        999.000000
# 5291                     0.0           3920.000000       1933.848559
# 4366                     0.0         125453.000000       1502.000000
# 6427                     2.0          20909.000000       2492.000000
# ...                      ...                   ...               ...
# 7724                     0.0         251094.946789        943.000000
# 1580                     0.0          44867.000000       1155.000000
# 132                      0.0          11326.000000       1699.000000
# 2585                     1.0          15682.000000       2461.000000
# 6782                     0.0         251094.946789       1933.848559
#
#       description.baths  ... recreation_facilities  shopping  washer_dryer  \
# 6040                2.0  ...                     0         0             0
# 277                 2.0  ...                     0         1             0
# 5291                0.0  ...                     0         0             0
# 4366                2.0  ...                     0         1             0
# 6427                4.0  ...                     0         1             0
# ...                 ...  ...                   ...       ...           ...
# 7724                2.0  ...                     0         1             1
# 1580                2.0  ...                     0         1             0
# 132                 2.0  ...                     0         0             1
# 2585                4.0  ...                     0         0             0
# 6782                0.0  ...                     0         0             0
#
#       basement view forced_air family_room dining_room  city_mean_price  \
# 6040         0    0          0           0           0    560232.142857
# 277          0    0          0           0           0    291081.250000
# 5291         0    1          0           0           0    522403.574850
# 4366         0    0          0           1           0    635975.614035
# 6427         1    0          1           0           1    237009.970238
# ...        ...  ...        ...         ...         ...              ...
# 7724         0    1          0           0           0    461060.890909
# 1580         0    0          0           0           1    303235.525000
# 132          0    0          0           0           0    181802.061728
# 2585         1    0          0           0           0    256955.000000
# 6782         0    0          0           0           0    194372.601852
#
#       state_mean_price
# 6040     302552.103659
# 277      284844.968553
# 5291     522403.574850
# 4366     635975.614035
# 6427     237009.970238
# ...                ...
# 7724     460899.089286
# 1580     303235.525000
# 132      181802.061728
# 2585     254990.877193
# 6782     204393.743802
#
# [1343 rows x 41 columns]

# %% [markdown]
# ## Extra Data - STRETCH
#
# > This doesn't need to be part of your Minimum Viable Product (MVP). We recommend you write a functional, basic pipeline first, then circle back and join new data if you have time
#
# > If you do this, try to write your downstream steps in a way it will still work on a dataframe with different features!
#
# - You're not limited to just using the data provided to you. Think/ do some research about other features that might be useful to predict housing prices.
# - Can you import and join this data? Make sure you do any necessary preprocessing and make sure it is joined correctly.
# - Example suggestion: could mortgage interest rates in the year of the listing affect the price?

# %%
# import, join and preprocess new data here

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5368 entries, 5285 to 890
# Data columns (total 41 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   list_price                             5368 non-null   float64
#  1   price_reduced_amount                   5368 non-null   float64
#  2   description.year_built                 5368 non-null   int32
#  3   description.baths_3qtr                 5368 non-null   float64
#  4   description.sold_price                 5368 non-null   object
#  5   description.baths_full                 5368 non-null   float64
#  6   description.baths_half                 5368 non-null   float64
#  7   description.lot_sqft                   5368 non-null   float64
#  8   description.sqft                       5368 non-null   float64
#  9   description.baths                      5368 non-null   float64
#  10  description.sub_type                   5368 non-null   object
#  11  description.garage                     5368 non-null   float64
#  12  description.stories                    5368 non-null   float64
#  13  description.beds                       5368 non-null   float64
#  14  description.type                       5368 non-null   object
#  15  lead_attributes.show_contact_an_agent  5368 non-null   object
#  16  location.address.postal_code           5368 non-null   object
#  17  location.address.state_code            5368 non-null   object
#  18  central_air                            5368 non-null   int64
#  19  central_heat                           5368 non-null   int64
#  20  community_outdoor_space                5368 non-null   int64
#  21  community_security_features            5368 non-null   int64
#  22  dishwasher                             5368 non-null   int64
#  23  fireplace                              5368 non-null   int64
#  24  hardwood_floors                        5368 non-null   int64
#  25  laundry_room                           5368 non-null   int64
#  26  single_story                           5368 non-null   int64
#  27  garage_1_or_more                       5368 non-null   int64
#  28  garage_2_or_more                       5368 non-null   int64
#  29  city_view                              5368 non-null   int64
#  30  two_or_more_stories                    5368 non-null   int64
#  31  recreation_facilities                  5368 non-null   int64
#  32  shopping                               5368 non-null   int64
#  33  washer_dryer                           5368 non-null   int64
#  34  basement                               5368 non-null   int64
#  35  view                                   5368 non-null   int64
#  36  forced_air                             5368 non-null   int64
#  37  family_room                            5368 non-null   int64
#  38  dining_room                            5368 non-null   int64
#  39  city_mean_price                        5368 non-null   float64
#  40  state_mean_price                       5368 non-null   float64
# dtypes: float64(13), int32(1), int64(21), object(6)
# memory usage: 1.7+ MB

# %%
# check outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=train_df['description.sold_price'], color='skyblue', fliersize=5, linewidth=1.5)
plt.xlabel('Sold Price', fontsize=12)
plt.title('Boxplot of Sold Prices', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# drop sold price > 4000000
train_df = train_df[train_df['description.sold_price'] <= 4000000]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=train_df['description.lot_sqft'], color='skyblue', fliersize=5, linewidth=1.5)
plt.xlabel('Sold Price', fontsize=12)
plt.title('Boxplot of lot_sqft', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# drop lot_sqft > 14000000
train_df = train_df[train_df['description.lot_sqft'] <= 14000000]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=train_df['description.sqft'], color='skyblue', fliersize=5, linewidth=1.5)
plt.xlabel('Sold Price', fontsize=12)
plt.title('Boxplot of sqft', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## EDA/ Visualization
#
# Remember all of the EDA that you've been learning about?  Now is a perfect time for it!
# - Look at distributions of numerical variables to see the shape of the data and detect outliers.
#     - Consider transforming very skewed variables
# - Scatterplots of a numerical variable and the target go a long way to show correlations.
# - A heatmap will help detect highly correlated features, and we don't want these.
#     - You may have too many features to do this, in which case you can simply compute the most correlated feature-pairs and list them
# - Is there any overlap in any of the features? (redundant information, like number of this or that room...)

# %%
# perform EDA here
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10, 6))
sns.scatterplot(x='description.sqft', y='description.sold_price', data=train_df, alpha=0.5, edgecolor=None)
plt.xlabel('Square Footage', fontsize=12)
plt.ylabel('Sold Price', fontsize=12)
plt.title('Scatter Plot of Sold Price vs. Square Footage', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='description.lot_sqft', y='description.sold_price', data=train_df, alpha=0.5, edgecolor=None)
plt.xlabel('Lot Square Footage', fontsize=12)
plt.ylabel('Sold Price', fontsize=12)
plt.title('Scatter Plot of Sold Price vs. Square Footage', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))  # Increase the figure size for better spacing
sns.barplot(x='description.type', y='description.sold_price', data=train_df)
plt.xlabel('Type', fontsize=12)
plt.ylabel('Sold Price', fontsize=12)
plt.title('Bar Plot of Sold Price vs. Type', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

plt.grid(True)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(train_df[['description.sold_price', 'description.sqft', 'description.lot_sqft','city_mean_price','state_mean_price']].corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Heatmap of Correlation Matrix', fontsize=14)
plt.show()

# %% [markdown]
# # Natane VISUALIZATION START

# %%
# computing correlation matrix
correlation_matrix = train_df.corr()

# set up the matplotlib figure
plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# pairplot to help visualize relationship between selected variables
features_to_plot = [
    'list_price',
    'description.sqft', 
    'description.beds', 
    'description.baths', 
    'city_mean_price', 
    'state_mean_price'
]

sns.pairplot(train_df[features_to_plot])
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %%
# countplot for visualzing properties features i.e central AC

plt.figure(figsize= (8,5))
sns.countplot(x='central_air', data=train_df)
plt.title('Count of Properties with Central Air Conditioning')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
# box plot for outlier detection

plt.figure(figsize=(12,6))
sns.boxplot(x='description.sub_type', y='list_price', data=train_df)
plt.title('Boxplot of List Price by Property Type')
plt.xticks(rotation=45) 
plt.show()

# %%
# scatterplot for price vs sqft
plt.figure(figsize=(12, 6))
sns.scatterplot(x='description.sqft', y='description.sold_price', data=train_df, alpha=0.6)
plt.title('List Price vs Square Footage')
plt.xlabel('Square Footage')
plt.ylabel('List Price')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Scaling and Finishing Up

# %% [markdown]
# Now is a great time to scale the data and save it once it's preprocessed.
# - You can save it in your data folder, but you may want to make a new `processed/` subfolder to keep it organized

# %%
train_df.to_csv('../preprocessed/train_df.csv', index=False)
test_df.to_csv('../preprocessed/test_df.csv', index=False)
